# %%
import pandas as pd

# load csv file nba_stats_1996-2022_raw.csv
df = pd.read_csv('../../data/raw/nba_stats_1996-2022_raw.csv')
    
# for each player id, combine all seasons into one row with the season as a multiindex, drop the original index
df = df.set_index(['PLAYER_ID', 'PLAYER_NAME', 'SEASON']).unstack(level=2)

# drop the Unnamed: 0 column
df = df.drop('Unnamed: 0', axis=1, level=0)

# switch multiindex levels for season and stats
df = df.swaplevel(0, 1, axis=1)
# resort columns so all seasons are grouped together and in ascending order
df = df.sort_index(axis=1, level=0)

print(df.head())

# print row for PLAYER_NAME = Jayson Tatum
print(df.loc[df.index.get_level_values(1) == 'Jayson Tatum'])

# save dataframe to csv file
df.to_csv('../../data/interim/nba_stats_seasons_stacked.csv', mode='w', header=True)
# Out:
# SEASON                   1996-97                                               \
#                              AGE DEF_RATING    GP   MIN NET_RATING OFF_RATING
# PLAYER_ID PLAYER_NAME
# 2         Byron Scott       36.0      100.3  79.0  18.2        5.9      106.2
# 3         Grant Long        31.0      100.8  65.0  18.0        4.2      105.0
# 7         Dan Schayes       38.0       97.7  45.0  12.0       -0.2       97.5
# 9         Sedale Threatt    35.0      105.7  21.0  16.0       -4.5      101.2
# 12        Chris King         NaN        NaN   NaN   NaN        NaN        NaN
#
# SEASON                                                          1997-98  ...  \
#                             PIE TEAM_ABBREVIATION       TEAM_ID     AGE  ...
# PLAYER_ID PLAYER_NAME                                                    ...
# 2         Byron Scott     0.095               LAL  1.610613e+09     NaN  ...
# 3         Grant Long      0.079               DET  1.610613e+09    32.0  ...
# 7         Dan Schayes     0.058               ORL  1.610613e+09    39.0  ...
# 9         Sedale Threatt  0.052               HOU  1.610613e+09     NaN  ...
# 12        Chris King        NaN               NaN           NaN     NaN  ...
#
# SEASON                   2021-22 2022-23                                \
#                          TEAM_ID     AGE DEF_RATING  GP MIN NET_RATING
# PLAYER_ID PLAYER_NAME
# 2         Byron Scott        NaN     NaN        NaN NaN NaN        NaN
# 3         Grant Long         NaN     NaN        NaN NaN NaN        NaN
# 7         Dan Schayes        NaN     NaN        NaN NaN NaN        NaN
# 9         Sedale Threatt     NaN     NaN        NaN NaN NaN        NaN
# 12        Chris King         NaN     NaN        NaN NaN NaN        NaN
#
# SEASON
#                          OFF_RATING PIE TEAM_ABBREVIATION TEAM_ID
# PLAYER_ID PLAYER_NAME
# 2         Byron Scott           NaN NaN               NaN     NaN
# 3         Grant Long            NaN NaN               NaN     NaN
# 7         Dan Schayes           NaN NaN               NaN     NaN
# 9         Sedale Threatt        NaN NaN               NaN     NaN
# 12        Chris King            NaN NaN               NaN     NaN
#
# [5 rows x 243 columns]
# SEASON                 1996-97                                               \
#                            AGE DEF_RATING  GP MIN NET_RATING OFF_RATING PIE
# PLAYER_ID PLAYER_NAME
# 1628369   Jayson Tatum     NaN        NaN NaN NaN        NaN        NaN NaN
#
# SEASON                                           1997-98  ...       2021-22  \
#                        TEAM_ABBREVIATION TEAM_ID     AGE  ...       TEAM_ID
# PLAYER_ID PLAYER_NAME                                     ...
# 1628369   Jayson Tatum               NaN     NaN     NaN  ...  1.610613e+09
#
# SEASON                 2022-23                                               \
#                            AGE DEF_RATING    GP   MIN NET_RATING OFF_RATING
# PLAYER_ID PLAYER_NAME
# 1628369   Jayson Tatum    25.0      110.8  74.0  36.9        8.5      119.2
#
# SEASON
#                           PIE TEAM_ABBREVIATION       TEAM_ID
# PLAYER_ID PLAYER_NAME
# 1628369   Jayson Tatum  0.167               BOS  1.610613e+09
#
# [1 rows x 243 columns]
